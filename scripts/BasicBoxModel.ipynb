# %%
import scipy as sp

# %%
# basic box model 
# starting point
inventory = 0
fin = 10 # per year
fout = 5 # per year
# run this 10 years 
for i in range(10):
    inventory += (fin-fout)
print('After 10 years the inventory has grown to {}'.format(inventory))

# %%
# Gulf of California example. 3 boxes deep. 2 boxes on surface 
# arbitrary numbers here. Inventories. Lets say of goldfish
PDW = 5 # Pacific deep water, 1000m to bottom
PIW = 10 # Pacific intermediate water 
SD = 5 # surface deep into gulf
SM = 10 # surface near the mouth

# %%
# in flows of goldfish
# first box named is on the receiving end. second box is where it is coming from 
# 9 equations
FinPDW_PIW = 2 * PIW
FinPIW_PDW = 0.5 * PDW
FinPIW_pacific = 0.5 * PIW
FinPIW_SD
FinPIW_SM
FinSD_PIW
FinSM_PIW
FinSD_SM
FinSM_SD

# out flows of goldfish
# 9 equations
FoutPDW_PIW
FoutPIW_PDW
FoutPIW_SD
FoutPIW_SM
FoutSD_PIW
FoutSD_SM
FoutSM_SD
FoutSM_PIW
FoutSM_pacific

# %%
# I went and read up on David Archers Coursera class about building your own models in Python. 
# From week 3, I am reinacting his 1D ice flow model

# %%
nX = 10                # number of grid points
domainWidth = 1e6      # meters
timeStep = 100         # years
nYears = 50000         # years
flowParam = 1e4        # m horizontal / yr
snowFall = 0.5         # m / y

# %%
# Initialize the elevations and flows
elevations = numpy.zeros(nX+2)
flows = numpy.zeros(nX+1)

# %%
flow[ix] = ( elevation[ix] - elevation[ix+1] ) / dX * flowParam  * \
    ( elevation[ix]+elevation[ix+1] ) / 2 / dX

# %%
# simple climate model scipy 
# one box model
